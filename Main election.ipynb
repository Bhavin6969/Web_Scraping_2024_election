# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website to scrape
url = 'https://results.eci.gov.in/PcResultGenJune2024/index.htm'

# Send a request to the website
response = requests.get(url)
a=response.raise_for_status()  # Check if the request was successful
print(response)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(r.text,"lxml")
table=soup.find("table",class_="table")
print(table)
# Out:
# <table class="table">
# <thead>
# <tr>
# <th style="text-align: left;">Party</th>
# <th style="text-align:right">Won</th>
# <th style="text-align:right">Leading</th>
# <th style="text-align:right">Total</th>
# </tr>
# </thead>
# <tbody>
# <tr class="tr">
# <td style="text-align:left">Bharatiya Janata Party - BJP</td>
# <td style="text-align:right">
# <a href="partywisewinresultState-369.htm">240</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">240</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Indian National Congress - INC</td>
# <td style="text-align:right">
# <a href="partywisewinresultState-742.htm">99</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
# ...

# %%
header=table.find_all("th")
print(header)
# Out:
# [<th style="text-align: left;">Party</th>, <th style="text-align:right">Won</th>, <th style="text-align:right">Leading</th>, <th style="text-align:right">Total</th>, <th>Total</th>, <th style="text-align:right">543</th>, <th style="text-align:right">0</th>, <th style="text-align:right">543</th>]

# %%
titles=[]
for i in header:
    title=i.text
    titles.append(title)
print(titles)
# Out:
# ['Party', 'Won', 'Leading', 'Total', 'Total', '543', '0', '543']

# %%
df=pd.DataFrame(columns=titles)
rows=table.find_all("tr")

# %%
print(df.columns)
print(len(df.columns))
# Out:
# Index(['Party', 'Won', 'Leading', 'Total', 'Total', '543', '0', '543'], dtype='object')
# 8

# %%
for i in rows[1:]:
    data = i.find_all("td")
    row = [tr.text for tr in data]
    print(len(row))
    break
# Out:
# 4

# %%
df = pd.DataFrame(columns=range(len(row)))  # Use this before your loop

# %%
row = row[:len(df.columns)]  # Truncate if row is too long
# or
row = row + [None] * (len(df.columns) - len(row))  # Pad if row is too short

# %%
all_rows = []

# Collect all rows
for i in rows[1:]:
    data = i.find_all("td")
    row = [tr.text for tr in data]
    all_rows.append(row)

# Create DataFrame after collecting all rows
df = pd.DataFrame(all_rows)

# Optionally, set column names if you know them
# df.columns = ['Column1', 'Column2', 'Column3', ...]

print(df)
# Out:
#                                                     0        1  \
# 0                        Bharatiya Janata Party - BJP  \n240\n
# 1                      Indian National Congress - INC   \n99\n
# 2                                Samajwadi Party - SP   \n37\n
# 3                 All India Trinamool Congress - AITC   \n29\n
# 4                     Dravida Munnetra Kazhagam - DMK   \n22\n
# 5                                  Telugu Desam - TDP   \n16\n
# 6                        Janata Dal  (United) - JD(U)   \n12\n
# 7      Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT    \n9\n
# 8   Nationalist Congress Party – Sharadchandra Paw...    \n8\n
# 9                                     Shiv Sena - SHS    \n7\n
# 10             Lok Janshakti Party(Ram Vilas) - LJPRV    \n5\n
# 11      Yuvajana Sramika Rythu Congress Party - YSRCP    \n4\n
# 12                         Rashtriya Janata Dal - RJD    \n4\n
# 13       Communist Party of India  (Marxist) - CPI(M)    \n4\n
# ...

# %%
df = df.drop(columns=[2, 3])  # Remove unnecessary columns
df = df.dropna()  # Remove any rows with NaN values

# Clean up the party names and seat numbers
df[0] = df[0].str.strip()  # Remove leading/trailing whitespace from party names
df[1] = df[1].str.strip().str.replace('\n', '').astype(int)  # Clean up and convert seat numbers to integers

# Rename the columns
df.columns = ['Party', 'Seats']

# Reset the index
df = df.reset_index(drop=True)

# Save to CSV
df.to_csv('election_results.csv', index=False)

print("CSV file 'election_results.csv' has been created.")
# Out:
# CSV file 'election_results.csv' has been created.
